# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Titanic-Dataset.csv')

# Display the first 5 rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Age - mean
df['Age'].fillna(value=df['Age'].mean(), inplace=True)

# Cabin - "DECK"
df['Cabin'].fillna(value="DECK", inplace=True)

# Embarked - mode
df['Embarked'].fillna(value=df['Embarked'].mode, inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_348\2236707917.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age'].fillna(value=df['Age'].mean(), inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_348\2236707917.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Cabin'].fillna(value="DECK", inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_348\2236707917.py:8: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Embarked'].fillna(value=df['Embarked'].mode, inplace=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       4 # Cabin - "DECK"
#       5 df['Cabin'].fillna(value="DECK", inplace=True)
#       6
#       7 # Embarked - mode
# ----> 8 df['Embarked'].fillna(value=df['Embarked'].mode, inplace=True)
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\generic.py:7086, in NDFrame.fillna(self, value, axis, inplace, limit)
#    7082                     "or Series, but you passed a "
#    7083                     f'"{type(value).__name__}"'
#    7084                 )
#    7085
# -> 7086             new_data = self._mgr.fillna(value=value, limit=limit, inplace=inplace)
#    7087
#    7088         elif isinstance(value, (dict, ABCSeries)):
#    7089             result = self if inplace else self.copy(deep=False)
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:461, in BaseBlockManager.fillna(self, value, limit, inplace)
#     457 if limit is not None:
#     458     # Do this validation even if we go through one of the no-op paths
#     459     limit = libalgos.validate_limit(None, limit=limit)
# --> 461 return self.apply(
#     462     "fillna",
#     463     value=value,
#     464     limit=limit,
#     465     inplace=inplace,
#     466 )
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1893, in ExtensionBlock.fillna(self, value, limit, inplace)
#    1891     if isinstance(self.dtype, IntervalDtype) and limit is not None:
#    1892         raise ValueError("limit must be None")
# -> 1893     return super().fillna(
#    1894         value=value,
#    1895         limit=limit,
#    1896         inplace=inplace,
#    1897     )
#    1898 if self._can_hold_na and not self.values._hasna:
#    1899     refs = self.refs
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1342, in Block.fillna(self, value, limit, inplace)
#    1339     mask[mask.cumsum(self.values.ndim - 1) > limit] = False
#    1341 if inplace:
# -> 1342     nbs = self.putmask(mask.T, value)
#    1343 else:
#    1344     nbs = self.where(value, ~mask.T)
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1774, in EABackedBlock.putmask(self, mask, new)
#    1770     values = values.T
#    1772 try:
#    1773     # Caller is responsible for ensuring matching lengths
# -> 1774     values._putmask(mask, new)
#    1775 except OutOfBoundsDatetime:
#    1776     raise
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\arrays\base.py:2585, in ExtensionArray._putmask(self, mask, value)
#    2582 else:
#    2583     val = value
# -> 2585 self[mask] = val
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:2237, in ArrowExtensionArray.__setitem__(self, key, value)
#    2234     key = key[0]
#    2236 key = check_array_indexer(self, key)
# -> 2237 value = self._maybe_convert_setitem_value(value)
#    2239 if com.is_null_slice(key):
#    2240     # fast path (GH50248)
#    2241     if (
#    2242         isinstance(value, (pa.Array, pa.ChunkedArray))
#    2243         and value.type == self._pa_array.type
#    2244         and len(value) == len(self)
#    2245     ):
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\arrays\string_arrow.py:298, in ArrowStringArray._maybe_convert_setitem_value(self, value)
#     296     else:
#     297         value = np.asarray(value)
# --> 298     if len(value) and not (
#     299         value.ndim == 1 and lib.is_string_array(value, skipna=True)
#     300     ):
#     301         raise TypeError(
#     302             "Invalid value for dtype 'str'. Value should be a "
#     303             "string or missing value (or array of those)."
#     304         )
#     305 return super()._maybe_convert_setitem_value(value)
#
# TypeError: len() of unsized object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
df.to_csv('Titanic-Dataset-Fixed.csv', index=False)
